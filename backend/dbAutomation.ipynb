# %%
import pandas as pd
import datetime

# %%
mainCsv = pd.read_csv(
    "/Users/sinarest/Downloads/OneDrive_1_13-03-2022/Google-Playstore.csv")

# %%
domainCsv = pd.read_csv(
    "/Users/sinarest/Downloads/OneDrive_1_13-03-2022/application_domain.csv")

# %%
domainCsv
# Out:
#                                        App Id       Category Content Rating
# 0                         com.ishakwe.gakondo      Adventure       Everyone
# 1                  com.webserveis.batteryinfo          Tools       Everyone
# 2                        com.doantiepvien.crm   Productivity       Everyone
# 3                     cst.stJoseph.ug17ucs548  Communication       Everyone
# 4                        com.horodyski.grower          Tools       Everyone
# ...                                       ...            ...            ...
# 2312939                         com.rxsj.ssjj   Role Playing           Teen
# 2312940              com.threedream.oruonline      Education       Everyone
# 2312941  datastructure.appoworld.datastucture      Education       Everyone
# 2312942                     ishan.devi.suktam  Music & Audio       Everyone
# 2312943             com.yyazilim.biliyormusun         Trivia       Everyone
#
# [2312944 rows x 3 columns]

# %%
appCsv = pd.read_csv(
    "/Users/sinarest/Downloads/OneDrive_1_13-03-2022/application.csv")

# %%
appDetsCsv = pd.read_csv(
    "/Users/sinarest/Downloads/OneDrive_1_13-03-2022/application_details.csv")

# %%
appDetsCsv
# Out:
#                                        App Id  Rating  Rating Count  Installs  \
# 0                         com.ishakwe.gakondo     0.0           0.0       10+
# 1                  com.webserveis.batteryinfo     4.4          64.0    5,000+
# 2                        com.doantiepvien.crm     0.0           0.0       50+
# 3                     cst.stJoseph.ug17ucs548     5.0           5.0       10+
# 4                        com.horodyski.grower     0.0           0.0      100+
# ...                                       ...     ...           ...       ...
# 2312939                         com.rxsj.ssjj     4.3       16775.0  100,000+
# 2312940              com.threedream.oruonline     0.0           0.0      100+
# 2312941  datastructure.appoworld.datastucture     0.0           0.0      100+
# 2312942                     ishan.devi.suktam     3.5           8.0    1,000+
# 2312943             com.yyazilim.biliyormusun     5.0          12.0      100+
#
# ...

# %%
newAppCsv = mainCsv[['App Id', 'App Name', 'Developer Id']].copy()
newAppCsv.to_csv('newApp.csv', index=False)

# %%
mainCsv.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
appDetsCsv
# Out:
#                                        App Id  Rating  Rating Count  Installs  \
# 0                         com.ishakwe.gakondo     0.0           0.0       10+
# 1                  com.webserveis.batteryinfo     4.4          64.0    5,000+
# 2                        com.doantiepvien.crm     0.0           0.0       50+
# 3                     cst.stJoseph.ug17ucs548     5.0           5.0       10+
# 4                        com.horodyski.grower     0.0           0.0      100+
# ...                                       ...     ...           ...       ...
# 2312939                         com.rxsj.ssjj     4.3       16775.0  100,000+
# 2312940              com.threedream.oruonline     0.0           0.0      100+
# 2312941  datastructure.appoworld.datastucture     0.0           0.0      100+
# 2312942                     ishan.devi.suktam     3.5           8.0    1,000+
# 2312943             com.yyazilim.biliyormusun     5.0          12.0      100+
#
# ...

# %%
print(len(appDetsCsv))
print(len(mainCsv))
appDetsCsv.columns
# Out:
# 2312944
# 2312944
# Index(['App Id', 'Rating', 'Rating Count', 'Installs', 'Minimum Installs',
#        'Maximum Installs', 'Free', 'Price', 'Size', 'Minimum Android',
#        'Released', 'Release_month', 'Release_year', 'Last Updated'],
#       dtype='object')

# %%
a =mainCsv[["App Id", "App Name", "Category", 'Developer Id']]

# %%
lastUpdDates = []
lastUpdMonths = []
lastUpdYears = []
lastUpdDates = appDetsCsv['Last Updated'].tolist()
# print(releaseDates)
for date in lastUpdDates:
    lastUpdMonths.append(date[0:3])
    lastUpdYears.append(date[-4:])
appDetsCsv.insert(14, "Last_Updated_month", lastUpdMonths, True)
appDetsCsv.insert(15, "Last_Updated_year", lastUpdYears, True)

# %%
appDetsCsv.drop(columns=['Released', 'Last Updated'])
# Out:
#                                        App Id  Rating  Rating Count  Installs  \
# 0                         com.ishakwe.gakondo     0.0           0.0       10+
# 1                  com.webserveis.batteryinfo     4.4          64.0    5,000+
# 2                        com.doantiepvien.crm     0.0           0.0       50+
# 3                     cst.stJoseph.ug17ucs548     5.0           5.0       10+
# 4                        com.horodyski.grower     0.0           0.0      100+
# ...                                       ...     ...           ...       ...
# 2312939                         com.rxsj.ssjj     4.3       16775.0  100,000+
# 2312940              com.threedream.oruonline     0.0           0.0      100+
# 2312941  datastructure.appoworld.datastucture     0.0           0.0      100+
# 2312942                     ishan.devi.suktam     3.5           8.0    1,000+
# 2312943             com.yyazilim.biliyormusun     5.0          12.0      100+
#
# ...

# %%
appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].str.replace(
    " and up", "")
appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].str.replace(
    "Varies with device", "10.0.0")
appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].str.replace("W", "")
appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].fillna("10.0.0")
appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].str[0:3]

appDetsCsv['Minimum Android'] = appDetsCsv['Minimum Android'].astype(float)
appDetsCsv['Minimum Android']
# Out:
# 0          7.1
# 1          5.0
# 2          4.0
# 3          4.0
# 4          4.1
#           ...
# 2312939    4.1
# 2312940    4.1
# 2312941    5.0
# 2312942    5.0
# 2312943    5.0
# Name: Minimum Android, Length: 2312944, dtype: float64

# %%
appDetsCsv['Release_month'] = appDetsCsv['Release_month'].apply(lambda x: pd.Timestamp(datetime.datetime.strptime(x,"%b")).month)
appDetsCsv['Last_Updated_month'] = appDetsCsv['Last_Updated_month'].apply(
    lambda x: pd.Timestamp(datetime.datetime.strptime(x, "%b")).month)

# %%
appDetsCsv['Size'] = appDetsCsv['Size'].str.replace("M", "")
appDetsCsv['Size'] = appDetsCsv['Size'].str.replace("G", "")
appDetsCsv['Size'] = appDetsCsv['Size'].str.replace(",", "")
appDetsCsv['Size'] = appDetsCsv['Size'].str.replace('Varies with device', "10")
appDetsCsv['Size'] = appDetsCsv['Size'].str.replace("k", "").astype(float)

# %%
appDetsCsv
# Out:
#                                        App Id  Rating  Rating Count  Installs  \
# 0                         com.ishakwe.gakondo     0.0           0.0       10+
# 1                  com.webserveis.batteryinfo     4.4          64.0    5,000+
# 2                        com.doantiepvien.crm     0.0           0.0       50+
# 3                     cst.stJoseph.ug17ucs548     5.0           5.0       10+
# 4                        com.horodyski.grower     0.0           0.0      100+
# ...                                       ...     ...           ...       ...
# 2312939                         com.rxsj.ssjj     4.3       16775.0  100,000+
# 2312940              com.threedream.oruonline     0.0           0.0      100+
# 2312941  datastructure.appoworld.datastucture     0.0           0.0      100+
# 2312942                     ishan.devi.suktam     3.5           8.0    1,000+
# 2312943             com.yyazilim.biliyormusun     5.0          12.0      100+
#
# ...

# %%
finalAppDets = appDetsCsv[['App Id', 'Free', 'Size','Price', 'Minimum Android']].copy()
finalAppDets["Free"] = finalAppDets["Free"].astype(str).str.replace("True", "Yes")
finalAppDets["Free"] = finalAppDets["Free"].astype(str).str.replace("False", "No")
finalAppDets
# Out:
#                                        App Id Free  Size  Price  \
# 0                         com.ishakwe.gakondo  Yes  10.0    0.0
# 1                  com.webserveis.batteryinfo  Yes   2.9    0.0
# 2                        com.doantiepvien.crm  Yes   3.7    0.0
# 3                     cst.stJoseph.ug17ucs548  Yes   1.8    0.0
# 4                        com.horodyski.grower  Yes   6.2    0.0
# ...                                       ...  ...   ...    ...
# 2312939                         com.rxsj.ssjj  Yes  77.0    0.0
# 2312940              com.threedream.oruonline  Yes  44.0    0.0
# 2312941  datastructure.appoworld.datastucture  Yes  29.0    0.0
# 2312942                     ishan.devi.suktam  Yes  10.0    0.0
# 2312943             com.yyazilim.biliyormusun  Yes   5.2    0.0
#
#          Minimum Android
# 0                    7.1
# 1                    5.0
# 2                    4.0
# 3                    4.0
# 4                    4.1
# ...                  ...
# ...

# %%
finalAppDets.to_csv("FinalAppDets.csv", index=False)

# %%
datesDf = appDetsCsv[['App Id','Release_month',	'Release_year',	'Last_Updated_month',	'Last_Updated_year']].copy()
datesDf
# Out:
#                                        App Id  Release_month Release_year  \
# 0                         com.ishakwe.gakondo              2         2020
# 1                  com.webserveis.batteryinfo              5         2020
# 2                        com.doantiepvien.crm              8         2020
# 3                     cst.stJoseph.ug17ucs548              9         2020
# 4                        com.horodyski.grower              2         2020
# ...                                       ...            ...          ...
# 2312939                         com.rxsj.ssjj              1         2020
# 2312940              com.threedream.oruonline              1         2020
# 2312941  datastructure.appoworld.datastucture              8         2020
# 2312942                     ishan.devi.suktam              8         2020
# 2312943             com.yyazilim.biliyormusun              8         2020
#
#          Last_Updated_month Last_Updated_year
# ...

# %%
datesDf.to_csv('dates.csv', index=False)

# %%
developercsv = pd.read_csv(
    "/Users/sinarest/Documents/DEV_Stuff/Python/cis4301/developer.csv")

# %%
unqDevs = list(developercsv["Developer Id"].unique())
unqDevs
# Out:
# ['Jean Confident Irénée NIYIZIBYOSE',
#  'Webserveis',
#  'Cabin Crew',
#  'Climate Smart Tech2',
#  'Rafal Milek-Horodyski',
#  'Imocci GmbH',
#  'android developer779',
#  'Mozaix LLC',
#  'Yilver Molina Hurtatiz',
#  'Free 2021 Themes for Emoji keyboard',
#  'MrScratch',
#  'Eqra Tech',
#  'Jie App',
#  'has.to.be gmbh',
#  'WayCali',
#  'pietechsolution',
#  'Hotels Attitude',
#  'TK Applications',
#  'Grit Technology',
#  'Human Droid Apps',
#  'Nitya Shree Developers',
#  'Bhavans, BHEL, Hyderabad',
#  'MailBee Games',
#  'bisgumah',
#  'GaryG Apps',
#  'Mitochondria Studios',
#  'GA software',
#  'TenSept Tools',
#  'Forumloft',
#  'CCIT.TMS',
#  'Phorest',
#  'Myler Media',
#  'Anuoluwapo',
#  'AL Hidayah Corporation',
#  'Beyond 2.0',
#  'NTO Serbia',
#  'Free Apps For Everyone',
#  'RaySemiSoft',
#  'BH App Development Ltd',
#  'TZLabs',
#  'Buradaoto',
#  'MoveNowApp',
#  'Legend APPS',
#  'Creators Bureau',
#  'Limonland Apps',
#  'MEPPEDIA',
#  'Kossta Tech Systems',
# ...

# %%
developercsv[developercsv["Developer Id"] == unqDevs[0]]["Developer Website"]
# Out:
# 0           https://beniyizibyose.tk/#/
# 2204232    https://augmented-future.com
# 2275431    http://augmented-future.com/
# Name: Developer Website, dtype: object

# %%
for devs in unqDevs:
    devDf = pd.DataFrame({"DeveloperID": devs,"Website":developercsv[developercsv["Developer Id"] == devs]["Developer Website"], "Email": developercsv[developercsv["Developer Id"] == devs]["Developer Email"]})
devDf
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb Cell 23' in <module>
#       <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000061?line=0'>1</a> for devs in unqDevs:
# ----> <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000061?line=1'>2</a>     devDf = pd.DataFrame({"DeveloperID": devs,"Website":developercsv[developercsv["Developer Id"] == devs]["Developer Website"], "Email": developercsv[developercsv["Developer Id"] == devs]["Developer Email"]})
#       <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000061?line=2'>3</a> devDf
#
# ...

# %%
developercsv.unique().to_csv('Developers.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb Cell 21' in <module>
# ----> <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000059?line=0'>1</a> developercsv.unique().to_csv('Developers.csv', index=False)
#
# File /Library/Python/3.8/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Library/Python/3.8/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Library/Python/3.8/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Library/Python/3.8/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
# ...

# %%
mainCsv['Released'][-1:-3]
# Out:
# Series([], Name: Released, dtype: object)

# %%
appID = mainCsv['App Id']
appName = mainCsv['App Name'].str.replace("'", "")
developerID = mainCsv['Developer Id'].str.replace("'", "")

# %%
developerWebsite = mainCsv['Developer Website'].str.replace("'", "")
developerEmail = mainCsv['Developer Email'].str.replace("'", "")

# %%
installsNum = mainCsv['Installs']
installsMaxNum = mainCsv['Maximum Installs']

# %%
ratingCount = mainCsv['Rating Count']
ratingValue = mainCsv['Rating']

# %%
contentRating = mainCsv['Content Rating']
category = mainCsv['Category'].unique()

# %%
contentRatingMap = {}
melt = []

# %%
c = mainCsv.melt('Content Rating', var_name=category[4])[
    'Content Rating'].unique()
print(c)
print(category)
# Out:
# ['Everyone' 'Teen' 'Mature 17+' 'Everyone 10+' 'Adults only 18+' 'Unrated']
# ['Adventure' 'Tools' 'Productivity' 'Communication' 'Social'
#  'Libraries & Demo' 'Lifestyle' 'Personalization' 'Racing'
#  'Maps & Navigation' 'Travel & Local' 'Food & Drink' 'Books & Reference'
#  'Medical' 'Puzzle' 'Entertainment' 'Arcade' 'Auto & Vehicles'
#  'Photography' 'Health & Fitness' 'Education' 'Shopping' 'Board'
#  'Music & Audio' 'Sports' 'Beauty' 'Business' 'Educational' 'Finance'
#  'News & Magazines' 'Casual' 'Art & Design' 'House & Home' 'Card' 'Events'
#  'Trivia' 'Weather' 'Strategy' 'Word' 'Video Players & Editors' 'Action'
#  'Simulation' 'Music' 'Dating' 'Role Playing' 'Casino' 'Comics'
#  'Parenting']

# %%
unqID = 100000
domainIDs = []
domainMap = {}

# %%
file = open('/Users/sinarest/Domain.sql','w')
for i in range(len(category)):
    c=[]
    c = mainCsv.melt('Content Rating', var_name=category[i])[
    'Content Rating'].unique()
    file.write("INSERT INTO domain VALUES ('{DomainID}', '{Category}','{Everyone}', '{Teen}', '{Mature17}', '{Everyone10}', '{Adults}', '{Unrated}');".format(
        DomainID=unqID, Category=category[i],Everyone=1 if 'Everyone'in c else 0,Teen=1 if 'Teen'in c else 0,Mature17=1 if 'Mature 17+'in c else 0,Everyone10=1 if 'Everyone 10+'in c else 0,Adults=1 if 'Adults only 18+'in c else 0,Unrated=1 if 'Unrated'in c else 0))
    file.write("\n")
    domainIDs.append(unqID)
    domainMap[category[i]]=unqID
    unqID = unqID+2
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
mainCsv
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
domainMap
# Out:
# {'Adventure': 100000,
#  'Tools': 100002,
#  'Productivity': 100004,
#  'Communication': 100006,
#  'Social': 100008,
#  'Libraries & Demo': 100010,
#  'Lifestyle': 100012,
#  'Personalization': 100014,
#  'Racing': 100016,
#  'Maps & Navigation': 100018,
#  'Travel & Local': 100020,
#  'Food & Drink': 100022,
#  'Books & Reference': 100024,
#  'Medical': 100026,
#  'Puzzle': 100028,
#  'Entertainment': 100030,
#  'Arcade': 100032,
#  'Auto & Vehicles': 100034,
#  'Photography': 100036,
#  'Health & Fitness': 100038,
#  'Education': 100040,
#  'Shopping': 100042,
#  'Board': 100044,
#  'Music & Audio': 100046,
#  'Sports': 100048,
#  'Beauty': 100050,
#  'Business': 100052,
#  'Educational': 100054,
#  'Finance': 100056,
#  'News & Magazines': 100058,
#  'Casual': 100060,
#  'Art & Design': 100062,
#  'House & Home': 100064,
#  'Card': 100066,
#  'Events': 100068,
#  'Trivia': 100070,
#  'Weather': 100072,
#  'Strategy': 100074,
#  'Word': 100076,
# ...

# %%
mainCsv.melt('Category', var_name='Adults only 18+')
# Out:
#                Category Adults only 18+  \
# 0             Adventure        App Name
# 1                 Tools        App Name
# 2          Productivity        App Name
# 3         Communication        App Name
# 4                 Tools        App Name
# ...                 ...             ...
# 53197707   Role Playing    Scraped Time
# 53197708      Education    Scraped Time
# 53197709      Education    Scraped Time
# 53197710  Music & Audio    Scraped Time
# 53197711         Trivia    Scraped Time
#
#                                                       value
# 0                                                   Gakondo
# 1                                       Ampere Battery Info
# 2                                                    Vibook
# 3         Smart City Trichy Public Service Vehicles 17UC...
# 4                                                   GROW.me
# ...                                                     ...
# ...

# %%
mainCsv
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
for c in category:
    melt = []
    melt = mainCsv.melt('Content Rating', var_name=category[40])[
        'Content Rating'].unique()
    contentRatingMap[c] = melt[0] if ('Everyone' in melt) else melt[1]
    print(contentRatingMap[c])
print(contentRatingMap)
# Out:
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# Everyone
# ...

# %%
category
# Out:
# array(['Adventure', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization', 'Racing',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Puzzle', 'Entertainment',
#        'Arcade', 'Auto & Vehicles', 'Photography', 'Health & Fitness',
#        'Education', 'Shopping', 'Board', 'Music & Audio', 'Sports',
#        'Beauty', 'Business', 'Educational', 'Finance', 'News & Magazines',
#        'Casual', 'Art & Design', 'House & Home', 'Card', 'Events',
#        'Trivia', 'Weather', 'Strategy', 'Word', 'Video Players & Editors',
#        'Action', 'Simulation', 'Music', 'Dating', 'Role Playing',
#        'Casino', 'Comics', 'Parenting'], dtype=object)

# %%
print(appID[0] + " "+appName[0] + " "+developerID[0] + " "+developerWebsite[0]+" "+developerEmail[0]+" "+str(installsNum[0]
                                                                                                             )+" "+str(installsMaxNum[0])+" "+str(ratingCount[0])+" "+str(ratingValue[0])+category[0]+" "+contentRating[0]+" ")
# Out:
# com.ishakwe.gakondo Gakondo Jean Confident Irénée NIYIZIBYOSE https://beniyizibyose.tk/#/ jean21101999@gmail.com 10+ 15 0.0 0.0Adventure Everyone

# %%
mainCsv.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
mainCsv['Size'] = mainCsv['Size'].str.replace("M", "")
mainCsv['Size'] = mainCsv['Size'].str.replace("G", "")
mainCsv['Size'] = mainCsv['Size'].str.replace(",", "")
mainCsv['Size'] = mainCsv['Size'].str.replace('Varies with device', "10")
appSize = mainCsv['Size'].str.replace("k", "").astype(float)
print(appSize)
# Out:
# 0          10.0
# 1           2.9
# 2           3.7
# 3           1.8
# 4           6.2
#            ...
# 2312939    77.0
# 2312940    44.0
# 2312941    29.0
# 2312942    10.0
# 2312943     5.2
# Name: Size, Length: 2312944, dtype: float64

# %%
mainCsv['Minimum Android'] = mainCsv['Minimum Android'].str.replace(
    " and up", "")
mainCsv['Minimum Android'] = mainCsv['Minimum Android'].str.replace(
    "Varies with device", "10.0.0")
mainCsv['Minimum Android'] = mainCsv['Minimum Android'].str.replace("W", "")
mainCsv['Minimum Android'] = mainCsv['Minimum Android'].str[0:3]
mainCsv['Minimum Android'] = mainCsv['Minimum Android'].fillna("10.0.0")
minAndroid = mainCsv['Minimum Android'].astype(float)

print(minAndroid)
# Out:
# 0          7.1
# 1          5.0
# 2          4.0
# 3          4.0
# 4          4.1
#           ...
# 2312939    4.1
# 2312940    4.1
# 2312941    5.0
# 2312942    5.0
# 2312943    5.0
# Name: Minimum Android, Length: 2312944, dtype: float64

# %%
price = []
price = appDetsCsv['Price']

# %%
# appDetsCsv['Release_month'] = datetime.datetime.strptime(appDetsCsv['Release_month'], "%b").month
# appDetsCsv['Release_month'] = appDetsCsv['Release_month'].apply(lambda x: pd.Timestamp(datetime.datetime.strptime(x,"%b")).month)
appDetsCsv['Last_Updated_month'] = appDetsCsv['Last_Updated_month'].apply(
    lambda x: pd.Timestamp(datetime.datetime.strptime(x, "%b")).month)
# for d in len(appDetsCsv['Release_month']):
#     appDetsCsv['Release_month'] = datetime.datetime.strptime(appDetsCsv['Release_month'][d], "%b").month
appDetsCsv.head()
# Out:
#                        App Id  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo     0.0           0.0      10+
# 1  com.webserveis.batteryinfo     4.4          64.0   5,000+
# 2        com.doantiepvien.crm     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548     5.0           5.0      10+
# 4        com.horodyski.grower     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  Size Minimum Android  \
# 0              10.0                15  True    0.0   10M      7.1 and up
# 1            5000.0              7662  True    0.0  2.9M      5.0 and up
# 2              50.0                58  True    0.0  3.7M    4.0.3 and up
# 3              10.0                19  True    0.0  1.8M    4.0.3 and up
# 4             100.0               478  True    0.0  6.2M      4.1 and up
#
#        Released  Release_month  Release_year  Last Updated  \
# 0  Feb 26, 2020              2          2020  Feb 26, 2020
# ...

# %%
lastupdm = appDetsCsv['Last_Updated_month']
lastupy = appDetsCsv['Last_Updated_year']

releasedm = appDetsCsv['Release_month']
releasedy = appDetsCsv['Release_year']

# %%
freeYN = []
for t in appDetsCsv["Free"]:
    freeYN.append("Yes" if t == True else "No")
print(freeYN[0:100])
print(len(freeYN))
# Out:
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
# 2312944

# %%
file = open('/Users/sinarest/AppDetails.sql', 'w')
for i in range(len(appID)):
    file.write("INSERT INTO appdetails VALUES ('{appID}', '{Free}', '{AppSize}', '{Price}', '{MinAndroid}', '{LastUpdatedMonth}', '{LastUpdatedYear}', '{ReleasedMonth}', '{ReleasedYear}');".format(
        appID=appID[i], AppSize=appSize[i], Price=price[i], MinAndroid=minAndroid[i], LastUpdatedMonth=lastupdm[i], LastUpdatedYear=lastupy[i], ReleasedMonth=releasedm[i], ReleasedYear=releasedy[i], Free=freeYN[i]))
    file.write("\n")

    #unqID = unqID+2
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
# file = open('/Users/sinarest/Domain.sql','w')
# for i in range(len(appID)):
#     file.write("INSERT INTO domain VALUES ('{DomainID}', '{Category}', '{ContentRating}', '{ID}');".format(DomainID=unqID, Category=category[i], ContentRating=contentRating[i], ID=appID[i]))
#     file.write("\n")
#     domainIDs.append(unqID)
#     unqID = unqID+2
#     #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

# file.close()

# %%
file = open('/Users/sinarest/Rating.sql', 'w')
for i in range(len(appID)):
    file.write("INSERT INTO rating VALUES ('{RatingCount}', '{Value}', '{ID}');".format(
        ID=appID[i], RatingCount=ratingCount[i], Value=ratingValue[i]))
    file.write("\n")
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
file = open('/Users/sinarest/Application.sql', 'w')
for i in range(len(appID)):
    file.write("INSERT INTO applications VALUES ('{ID}', '{Name}', '{devID}');".format(
        ID=appID[i], Name=appName[i], devID=developerID[i]))
    file.write("\n")
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
file = open('/Users/sinarest/Developer.sql', 'w')
for i in range(len(appID)):
    file.write("INSERT INTO developer VALUES ('{ID}', '{Website}', '{Email}');".format(
        ID=developerID[i], Website=developerWebsite[i], Email=developerEmail[i]))
    file.write("\n")
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
file = open('/Users/sinarest/Installs.sql', 'w')
for i in range(len(appID)):
    file.write("INSERT INTO installs VALUES ('{Number}', '{MaxInstalls}', '{ID}');".format(
        ID=appID[i], Number=installsNum[i], MaxInstalls=installsMaxNum[i]))
    file.write("\n")
    #print("INSERT INTO domains VALUES ({domainID}, {category}, {content_rating}, {appID});".format(domainID=unqID, category=category[i], content_rating=contentRatind[i], appID=appId[i]))

file.close()

# %%
# installsDF
# Out:
# []

# %%
installsNum[0:10]
# Out:
# 0        10+
# 1     5,000+
# 2        50+
# 3        10+
# 4       100+
# 5        50+
# 6     1,000+
# 7       500+
# 8        10+
# 9    50,000+
# Name: Installs, dtype: object

# %%
installsDF = pd.DataFrame({"ID": mainCsv['App Id'],"Install_Number":installsNum, "Max_Installs": installsMaxNum})

# %%
installsDF.to_csv("installs.csv", index=False)

# %%
mainCsv
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
mainCsv["Content Rating"].value_counts()
# Out:
# Everyone           2022089
# Teen                196375
# Mature 17+           60289
# Everyone 10+         33901
# Unrated                154
# Adults only 18+        136
# Name: Content Rating, dtype: int64

# %%
cr = mainCsv[["App Id", "Content Rating"]]
cr
# Out:
#                                        App Id Content Rating
# 0                         com.ishakwe.gakondo       Everyone
# 1                  com.webserveis.batteryinfo       Everyone
# 2                        com.doantiepvien.crm       Everyone
# 3                     cst.stJoseph.ug17ucs548       Everyone
# 4                        com.horodyski.grower       Everyone
# ...                                       ...            ...
# 2312939                         com.rxsj.ssjj           Teen
# 2312940              com.threedream.oruonline       Everyone
# 2312941  datastructure.appoworld.datastucture       Everyone
# 2312942                     ishan.devi.suktam       Everyone
# 2312943             com.yyazilim.biliyormusun       Everyone
#
# [2312944 rows x 2 columns]

# %%
cr.to_csv('ContentR.csv', index=False)

# %%
ratingsDF = pd.DataFrame({"ID": mainCsv['App Id'],"Rating_Count":ratingCount, "Value": ratingValue})
ratingsDF
# Out:
#                                            ID  Rating_Count  Value
# 0                         com.ishakwe.gakondo           0.0    0.0
# 1                  com.webserveis.batteryinfo          64.0    4.4
# 2                        com.doantiepvien.crm           0.0    0.0
# 3                     cst.stJoseph.ug17ucs548           5.0    5.0
# 4                        com.horodyski.grower           0.0    0.0
# ...                                       ...           ...    ...
# 2312939                         com.rxsj.ssjj       16775.0    4.3
# 2312940              com.threedream.oruonline           0.0    0.0
# 2312941  datastructure.appoworld.datastucture           0.0    0.0
# 2312942                     ishan.devi.suktam           8.0    3.5
# 2312943             com.yyazilim.biliyormusun          12.0    5.0
#
# [2312944 rows x 3 columns]

# %%
ratingsDF.to_csv("ratings.csv", index=False)

# %%
domainCSV = pd.read_csv("/Users/sinarest/Music/domain.csv")

# %%
# ids = {}
# # for i in range(len(domainCSV)):
# ids[domainCSV["Category"]] = domainCSV["DOMAIN_ID"]
# ids

x = dict(zip(domainCSV["Category"], domainCSV["DOMAIN_ID"]))

x
# Out:
# {'Adventure': 100000,
#  'Tools': 100002,
#  'Productivity': 100004,
#  'Communication': 100006,
#  'Social': 100008,
#  'Libraries and Demo': 100010,
#  'Lifestyle': 100012,
#  'Personalization': 100014,
#  'Racing': 100016,
#  'Maps and Navigation': 100018,
#  'Travel and Local': 100020,
#  'Food and Drink': 100022,
#  'Books and Reference': 100024,
#  'Medical': 100026,
#  'Puzzle': 100028,
#  'Entertainment': 100030,
#  'Arcade': 100032,
#  'Auto and Vehicles': 100034,
#  'Photography': 100036,
#  'Health and Fitness': 100038,
#  'Education': 100040,
#  'Shopping': 100042,
#  'Board': 100044,
#  'Music and Audio': 100046,
#  'Sports': 100048,
#  'Beauty': 100050,
#  'Business': 100052,
#  'Educational': 100054,
#  'Finance': 100056,
#  'News and Magazines': 100058,
#  'Casual': 100060,
#  'Art and Design': 100062,
#  'House and Home': 100064,
#  'Card': 100066,
#  'Events': 100068,
#  'Trivia': 100070,
#  'Weather': 100072,
#  'Strategy': 100074,
#  'Word': 100076,
# ...

# %%
for i in x.keys():
    x.keys()[i].replace("and", "&")
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb Cell 69' in <module>
#       <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000073?line=0'>1</a> for i in x.keys():
# ----> <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000073?line=1'>2</a>     x.keys()[i].replace("and", "&")
#       <a href='vscode-notebook-cell:/Users/sinarest/Documents/DEV_Stuff/Flutter/playstore-data-analysis/backend/dbAutomation.ipynb#ch0000073?line=2'>3</a> x
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
domainCSV = domainCSV.rename(columns={"CATEGORY":'Category'})
domainCSV
# Out:
#     DOMAIN_ID                   Category  EVERYONE  TEEN  MATURE  EVERYONE10  \
# 0      100000                  Adventure         1     1       1           1
# 1      100002                      Tools         1     1       1           1
# 2      100004               Productivity         1     1       1           1
# 3      100006              Communication         1     1       1           1
# 4      100008                     Social         1     1       1           1
# 5      100010         Libraries and Demo         1     1       1           1
# 6      100012                  Lifestyle         1     1       1           1
# 7      100014            Personalization         1     1       1           1
# 8      100016                     Racing         1     1       1           1
# 9      100018        Maps and Navigation         1     1       1           1
# 10     100020           Travel and Local         1     1       1           1
# ...

# %%
a=a.replace({"Category": x})
a
# Out:
#                                        App Id  \
# 0                         com.ishakwe.gakondo
# 1                  com.webserveis.batteryinfo
# 2                        com.doantiepvien.crm
# 3                     cst.stJoseph.ug17ucs548
# 4                        com.horodyski.grower
# ...                                       ...
# 2312939                         com.rxsj.ssjj
# 2312940              com.threedream.oruonline
# 2312941  datastructure.appoworld.datastucture
# 2312942                     ishan.devi.suktam
# 2312943             com.yyazilim.biliyormusun
#
#                                                   App Name  Category  \
# 0                                                  Gakondo    100000
# 1                                      Ampere Battery Info    100002
# 2                                                   Vibook    100004
# 3        Smart City Trichy Public Service Vehicles 17UC...    100006
# ...

# %%
a.to_csv("ApplicationsF.csv", index=False)

# %%
b = pd.merge(a, domainCSV, on="Category")
b.set_index("Category", inplace=True)

# %%
a["Category"] = a["Category"].str.replace("&", "and")
# Out:
# /var/folders/4w/skzrk_cn68vdjm8lkhtxxbq00000gn/T/ipykernel_52777/2919874609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a["Category"] = a["Category"].str.replace("&", "and")

# %%
a
# Out:
#                                        App Id  \
# 0                         com.ishakwe.gakondo
# 1                  com.webserveis.batteryinfo
# 2                        com.doantiepvien.crm
# 3                     cst.stJoseph.ug17ucs548
# 4                        com.horodyski.grower
# ...                                       ...
# 2312939                         com.rxsj.ssjj
# 2312940              com.threedream.oruonline
# 2312941  datastructure.appoworld.datastucture
# 2312942                     ishan.devi.suktam
# 2312943             com.yyazilim.biliyormusun
#
#                                                   App Name         Category  \
# 0                                                  Gakondo        Adventure
# 1                                      Ampere Battery Info            Tools
# 2                                                   Vibook     Productivity
# 3        Smart City Trichy Public Service Vehicles 17UC...    Communication
# ...
